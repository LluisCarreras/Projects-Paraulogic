# %%
idx = 1
chars = list('torl')
init = 'tro'

for a in chars:
    for b in chars:
        for c in chars:
            for d in chars:
                result = init+'-'+a+b+c+d
                if 'l' in result:
                    print(idx, '\t', result)
                    idx += 1
# Out:
# 1 	 tro-tttl
# 2 	 tro-ttol
# 3 	 tro-ttrl
# 4 	 tro-ttlt
# 5 	 tro-ttlo
# 6 	 tro-ttlr
# 7 	 tro-ttll
# 8 	 tro-totl
# 9 	 tro-tool
# 10 	 tro-torl
# 11 	 tro-tolt
# 12 	 tro-tolo
# 13 	 tro-tolr
# 14 	 tro-toll
# 15 	 tro-trtl
# 16 	 tro-trol
# 17 	 tro-trrl
# 18 	 tro-trlt
# 19 	 tro-trlo
# 20 	 tro-trlr
# 21 	 tro-trll
# 22 	 tro-tltt
# 23 	 tro-tlto
# 24 	 tro-tltr
# 25 	 tro-tltl
# 26 	 tro-tlot
# 27 	 tro-tloo
# 28 	 tro-tlor
# 29 	 tro-tlol
# 30 	 tro-tlrt
# 31 	 tro-tlro
# 32 	 tro-tlrr
# 33 	 tro-tlrl
# 34 	 tro-tllt
# 35 	 tro-tllo
# 36 	 tro-tllr
# 37 	 tro-tlll
# 38 	 tro-ottl
# 39 	 tro-otol
# 40 	 tro-otrl
# 41 	 tro-otlt
# 42 	 tro-otlo
# 43 	 tro-otlr
# 44 	 tro-otll
# 45 	 tro-ootl
# 46 	 tro-oool
# 47 	 tro-oorl
# 48 	 tro-oolt
# 49 	 tro-oolo
# 50 	 tro-oolr
# 51 	 tro-ooll
# 52 	 tro-ortl
# 53 	 tro-orol
# 54 	 tro-orrl
# 55 	 tro-orlt
# 56 	 tro-orlo
# 57 	 tro-orlr
# 58 	 tro-orll
# 59 	 tro-oltt
# 60 	 tro-olto
# 61 	 tro-oltr
# 62 	 tro-oltl
# 63 	 tro-olot
# ...
