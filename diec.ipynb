# %%
import requests
from bs4 import BeautifulSoup

# %%
# URL of the webpage you want to scrape
url = 'https://www.vilaweb.cat/paraulogic/'  # Replace with your target URL

# Send a request to fetch the webpage content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the webpage content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    print(soup)

    # Find all DIVs with the class "hex-link"
    divs = soup.find_all('div', class_='hex-in')
    
    #print(divs)

    # Loop through each div to access the nested structure
    for div in divs:
        # Find the <a> tag inside the div with the class "hex-link"
        a_tag = div.find('a', class_='hex-link')
        
        if a_tag:
            # Find the <p> tag inside the <a> tag
            p_tag = a_tag.find('p')
            
            if p_tag:
                # Get the text inside the <p> tag
                p_text = p_tag.get_text(strip=True)
                print(f"P Text: {p_text}")
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
# Out:
# <!DOCTYPE html>
#
# <html lang="ca">
# <head>
# <title>Paraulògic</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Juga al Paraulògic." name="description"/>
# <base href="/paraulogic/"/>
# <link href="https://www.vilaweb.cat/paraulogic/" rel="canonical"/>
# <link href="favicon.svg" rel="icon" type="image/svg+xml"/>
# <link href="apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="site.webmanifest" rel="manifest"/>
# <link href="//fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="//fonts.gstatic.com" rel="preconnect"/>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <meta content="https://paraulogic.vilaweb.cat/" property="mrf:canonical">
# <script type="text/javascript">
#   function e(e){var t=!(arguments.length>1&&void 0!==arguments[1])||arguments[1],c=document.createElement("script");c.src=e,t?c.type="module":(c.async=!0,c.type="text/javascript",c.setAttribute("nomodule",""));var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(c,n)}function t(t,c,n){var a,o,r;null!==(a=t.marfeel)&&void 0!==a||(t.marfeel={}),null!==(o=(r=t.marfeel).cmd)&&void 0!==o||(r.cmd=[]),t.marfeel.config=n,t.marfeel.config.accountId=c;var i="https://sdk.mrf.io/statics";e("".concat(i,"/marfeel-sdk.js?id=").concat(c),!0),e("".concat(i,"/marfeel-sdk.es5.js?id=").concat(c),!1)}!function(e,c){var n=arguments.length>2&&void 0!==arguments[2]?arguments[2]:{};t(e,c,n)}
#   (window,165 /*accountId*/,{adsTrackingFromClient:true} /*config*/);
#   </script>
# <link href="//fonts.googleapis.com/css2?family=Open+Sans:wght@400;600&amp;display=swap" rel="stylesheet"/>
# <style>h1,h2,h3,h4,h5,h6,ol,p,ul{margin:0;padding:0}h2{font-weight:400}body{margin:0 auto;max-width:800px;display:flex;flex-direction:column;font-family:'Open Sans',sans-serif;line-height:30px;position:relative;color:#000;background:#fff}body.dark{color:#fff;background:#212529}body.book{background:#ebf7fd}body.quadern{background:#ebf7fd}body,html{touch-action:manipulation}a{color:#000;background-color:transparent;text-decoration:none;font-weight:bolder}.dark a{color:#fff}a:hover{text-decoration:underline}b,strong{font-weight:bolder}img{border-style:none}.scoreboard{display:flex;justify-content:center;flex-direction:column;margin-bottom:20px}.scoreboard>div{align-self:center;line-height:1.5;margin:4px 20px}#stars{margin-top:-10px;color:#63bcca;user-select:none;letter-spacing:3px;text-indent:3px}#data{display:flex;justify-content:space-around}.pangrama #stars{color:#fc0}span.pangrama{font-weight:bolder;color:#ec4a49}#definition,.sol-def{font-size:10pt;font-family:Verdana,Geneva,Tahoma,sans-serif;margin-top:0;margin-bottom:10px}#definition a,.sol-def a{cursor:initial;text-decoration:none}.title{font-weight:700}sup{top:-.5em}sub,sup{position:relative;font-size:90%;line-height:0;vertical-align:baseline}.versaleta{font-variant:small-caps;text-align:justify}#definition h3,.sol-def h3{font-weight:400;font-size:14px;color:#e3282a}.tagline{font-style:italic;text-align:right}.italic{font-style:italic}.bold{font-style:italic;font-weight:700}.bolditalic{font-style:italic;font-weight:700}div.copyright{margin-top:10px}.scoreboard div.copyright{margin-bottom:20px}#hex-grid{display:grid;grid-gap:6px;grid-template-columns:repeat(6,2fr);padding-bottom:30px;width:250px;margin:0 auto;font-size:.9em;list-style-type:none;overflow:hidden}.container-hexgrid{display:flex;flex-direction:column;align-items:center;z-index:0}.hex{grid-column-end:span 2;position:relative;user-select:none;pointer-events:none}.hex::after{content:'';display:block;padding-bottom:86.602%}.hex p{text-transform:uppercase;width:100%;padding:38%;box-sizing:border-box;font-size:1.4em;color:#000}.hex #center-letter p{color:#fff}.hex-in{position:absolute;width:100%;padding-bottom:115.47%;overflow:hidden;transform:rotate3d(0,0,1,-60deg) skewY(30deg);pointer-events:none}.hex-in *{position:absolute}#center-letter{background-color:#ec4a49}.hex-link{display:block;width:100%;height:100%;text-align:center;background-color:#63bcca;overflow:hidden;transform:skewY(-30deg) rotate3d(0,0,1,60deg);outline:0;pointer-events:auto;cursor:pointer;-webkit-tap-highlight-color:transparent}.no-pointer{cursor:inherit;background-color:#ccc!important}.hex-link:not(.no-pointer):focus p,.hex-link:not(.no-pointer):hover p{box-shadow:inset 0 0 100px 100px rgba(255,255,255,.1)}.hex:nth-child(5n+1){grid-column-start:2}.hex:nth-child(5n+3){grid-column-start:1}#test-word{text-align:center}#cursor{font-weight:100;color:#63bcca;margin-top:-5px}.cursor-container{font-size:2rem;position:relative;margin:30px auto;margin-top:10px}h1{position:relative;text-align:center;margin-top:30px}#level{user-select:none}#input-word{display:flex;height:30px}.style_input{border-bottom:solid;border-width:1px;border-top:none;border-left:none;border-right:none;border-color:#dedede;width:90%;font-size:14px;background-color:#fbfbfb;margin-bottom:8px;padding:8px;-ms-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box;-webkit-box-sizing:content-box}.button-container{display:inline-flex;margin:30px auto;width:300px}button{overflow:visible;text-transform:none;background-color:#fff;border:2px solid #e7e7e7;margin:0 auto;color:#000;padding:0 15px;text-align:center;text-decoration:none;display:inline-block;font-size:.8em;border-radius:30px;cursor:pointer;outline:0;padding:12px;user-select:none;touch-action:none}button[type=button-secondary]{overflow:visible;text-transform:none;background-color:#fff;margin:0 auto;color:#000;padding:0 15px;text-align:center;text-decoration:none;display:inline-block;font-size:.8em;cursor:pointer;bor ...
# <script>
#       window.googletag = window.googletag || {
#         cmd: []
#       };
#       googletag.cmd.push(function() {
#
#         var mapping_interstitial = googletag.sizeMapping()
#             .addSize([1024, 0], [
#               [800, 600]
#             ])
#             .addSize([0, 0], [
#               [320, 480]
#             ])
#             .build();
#
#         googletag.defineSlot('/75638159/2135658585877465', [[320, 480], [800, 600]], 'div-gpt-ad-1678720458858-0').addService(googletag.pubads()).defineSizeMapping(mapping_interstitial);;
#
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#   </script>
# </meta></head>
# <body data-joc="2024-10-16" data-joc-ant="2024-10-15" data-joc-est="present">
# <script>
# function includeHTML(container, template) {
#   var file, xhttp, elmnt;
#   elmnt = document.getElementById(container);
#   file = template;
#   if (file) {
#     xhttp = new XMLHttpRequest();
#     xhttp.onreadystatechange = function() {
#       if (this.readyState == 4) {
#         if (this.status == 200) {elmnt.innerHTML = this.responseText;}
#         if (this.status == 404) {elmnt.innerHTML = "Page not found.";}
#       }
#     }
#     xhttp.open("GET", file, true);
#     xhttp.send();
#     return;
#   }
# };
# </script>
# <h1><a class="logo-vilaweb" href="//www.vilaweb.cat" title="Ves a VilaWeb"><img alt="VilaWeb" height="42" src="img/logo_vilaweb.svg" width="42"/></a>
# <a href=""><img alt="Paraulògic" class="logo" height="54" src="img/logotip.svg" width="220"/></a>
# </h1>
# <div class="modal" id="info_modal" style="display:none; z-index:300;">
# <div class="container">
# <div class="close-icon-container" style="position: fixed;right: 0;">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <ul class="modal-content" style="text-align: center;">
# <div id="info_modal_content"></div>
# <button class="close-button" title="Tanca la finestra" type="button">Tanca</button>
# </ul>
# </div>
# </div>
# <div class="modal" id="signup" style="display:none;">
# <div class="container">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <h2><b>Registre</b></h2>
# <div id="register_form">
# <ul class="modal-content" style="text-align: -webkit-center;text-align: -moz-center;">
# <div class="stats-text">Si ja ets usuari, inicia sessió <a class="link" id="openlogin_button" style="cursor: pointer;">ací</a>.</div>
# <span class="error_msg_orange" id="signup-default_msg-errorspan" style="display:none"></span>
# <form class="form center-div" id="signupForm">
# <div class="input-group">
# <div class="error_msg" id="signup-email-errorspan" style="display:none"></div>
# <input class="input style_input" id="signup-email" placeholder="Correu electrònic *" type="text"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="signup-password-errorspan" style="display:none"></div>
# <input class="input style_input" id="signup-password" placeholder="Contrasenya *" type="password"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="signup-password_second-errorspan" style="display:none"></div>
# <input class="input style_input" id="signup-password_second" placeholder="Repeteix la contrasenya *" type="password"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="signup-phone-errorspan" style="display:none"></div>
# <input class="input style_input" id="signup-phone" placeholder="Telèfon" type="phone"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="signup-username-errorspan" style="display:none"></div>
# <input class="input style_input" id="signup-username" placeholder="Nom *" type="text"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="signup-surname-errorspan" style="display:none"></div>
# <input class="input style_input" id="signup-surname" placeholder="Cognoms *" type="text"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="signup-comarca-errorspan" style="display:none"></div>
# <select class="input style_input" id="signup-comarca" placeholder="Comarca *" type="text"></select>
# </div>
# <br/>
# <div class="input-group center-div">
# <div class="subtext">
# <div class="error_msg" id="signup-accept_privacy_policy-errorspan" style="display:none"></div>
# <input class="input" id="signup-accept_privacy_policy" type="checkbox"/>Accepto <a class="link" id="open_legal_advice" style="cursor: pointer;">l'avís legal</a> i la <a class="link" id="open_legal_politica_privadesa" style="cursor: pointer;">política de privadesa</a> i també rebre comunicacions relacionades amb el meu registre al Paraulògic.
#                 <br/><input class="input" id="signup-accept_mailing" type="checkbox"/>Vull rebre el Butlletí del Paraulògic i comunicacions sobre novetats que em puguin interessar.
#               </div>
# </div>
# <br/>
# <div class="center-div">
# <button class="button" type="submit">Envia</button>
# </div>
# <br/>
# </form>
# </ul>
# </div>
# <div id="register_message" style="display: none">
# <ul class="modal-content" style="text-align: center;">
# <b>Moltes gràcies per registrar-te, <div class="player_name"></div></b>
# <br/>
#           Revisa la teva bústia. Hem enviar un missatge perquè validis la teva adreça de correu electrònic.
#           <br/>
#           Pots posar-te en contacte amb nosaltres escrivint a <a class="link" href="mailto:paraulogic@vilaweb.cat">paraulogic@vilaweb.cat</a>
# <div class="close-button-container">
# <br/>
# <button class="close-button" title="Tanca la finestra" type="button">Tanca</button>
# </div>
# </ul>
# </div>
# </div>
# </div>
# <div class="modal" id="login" style="display:none;">
# <div class="container">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <h2><b>Identifica't</b></h2>
# <ul class="modal-content">
# <form class="form center-div" id="loginForm">
# <div class="input-group">
# <div class="error_msg" id="login-email-errorspan" style="display:none"></div>
# <input class="input style_input" id="login-email" placeholder="Correu electrònic *" type="text"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="login-password-errorspan" style="display:none"></div>
# <input class="input style_input" id="login-password" placeholder="Contrasenya *" type="password"/>
# </div>
# <br/>
# <div class="center-div">
# <div class="error_msg" id="login-default_msg-errorspan" style="display:none"></div>
# <button class="button" type="submit">Envia</button>
# <div class="subtext">
# <div style="font-size: 13px;line-height: normal"><a class="link" id="recover_password" style="cursor: pointer;">Recuperar contrasenya</a></div>
# <br/>
# <div style="font-size: 13px;line-height: normal">Si encara no estàs registrat, pots fer-ho <a class="link" id="openregister_button" style="cursor: pointer;">ací</a>.</div>
# </div>
# </div>
# <br/>
# </form>
# </ul>
# </div>
# </div>
# <div class="modal" id="dades" style="display:none; text-align: -webkit-center; text-align: -moz-center;">
# <div class="container">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <h2><b>Les teves dades</b></h2>
# <ul class="modal-content">
# <div class="error_msg_orange" id="dades-good_msg-errorspan" style="display:none;text-align-last: center;font-weight: bold;"></div>
# <form class="form center-div" id="dadesForm">
# <div class="input-group">
# <div class="error_msg" id="dades-nom-errorspan" style="display:none"></div>
# <div class="dada_text">Nom</div>
# <label class="asterisc" data-domain="*"></label>
# <input class="input dada_input" id="dades-nom" type="text"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="dades-cognoms-errorspan" style="display:none"></div>
# <div class="dada_text">Cognom</div>
# <label class="asterisc" data-domain="*"></label>
# <input class="input dada_input" id="dades-cognoms" type="text"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="dades-telefon-errorspan" style="display:none"></div>
# <div class="dada_text">Telèfon</div>
# <input class="input dada_input" id="dades-telefon" type="text"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="dades-email-errorspan" style="display:none"></div>
# <div class="dada_text">Correu electrònic</div>
# <label class="asterisc" data-domain="*"></label>
# <input class="input dada_input" id="dades-email" readonly="" type="text"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="dades-comarca-errorspan" style="display:none"></div>
# <div class="dada_text">Comarca</div>
# <label class="asterisc" data-domain="*"></label>
# <select class="input dada_input" disabled="" id="dades-comarca" type="text"></select>
# </div>
# <br/>
# <div class="error_msg" id="dades-default_msg-errorspan" style="display:none"></div>
# <div class="center-div" style="display:flex;max-width:800px;margin:20px auto;margin-top:10px;">
# <div style="width: 50%;">
# <button class="button" style="width: 60%;font-size: 11px;" type="submit">Modifica</button>
# </div>
# <div style="width: 50%;">
# <button class="button" id="close_session_button" style="color:white; background-color: #ec4949;width: 60%;font-size: 11px;">Tanca la sessió</button>
# </div>
# </div>
# <br/>
# <div style="width: 90%;text-align: left;font-size: 13px;line-height: normal;">
# <b>Pots posar-te en contacte amb nosaltres escrivint a <a class="link" href="mailto:paraulogic@vilaweb.cat">paraulogic@vilaweb.cat</a></b>
# </div>
# </form>
# </ul>
# </div>
# </div>
# <div class="modal" id="recoverPass" style="display:none;">
# <div class="container">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <h2><b>Recuperar contrasenya</b></h2>
# <ul class="modal-content" style="text-align: -webkit-center;text-align: -moz-center;">
# <span class="error_msg_orange" id="recoverPass-default_msg-errorspan" style="display:none">Correu de recuperació enviat!</span>
# <form class="form center-div" id="recoverPassForm">
# <div class="input-group">
# <div class="error_msg" id="recoverPass-email-errorspan" style="display:none"></div>
# <input class="input style_input" id="recoverPass-email" placeholder="Correu electrònic *" type="text"/>
# </div>
# <br/>
# <button class="button" type="submit">Envia</button>
# <br/>
# <div class="subtext">
# <br/>
# <div style="font-size: 13px;line-height: normal">Escriu el teu correu electrònic i t'enviarem un missatge amb les indicacions per canviar la teva contrasenya.</div>
# </div>
# </form>
# </ul>
# </div>
# </div>
# <div class="modal" id="resetPass" style="display:none;">
# <div class="container">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <h2><b>Recuperar contrasenya</b></h2>
# <ul class="modal-content">
# <form class="form center-div" id="resetPassForm">
# <span class="error_msg_orange" id="resetPass-default_msg-errorspan" style="display:none">Contasenya modificada satisfactoriament</span>
# <div class="input-group">
# <div class="stats-text" style="text-align: left;width: 90%;">Introdueix la nova contrasenya:</div>
# <div class="error_msg" id="resetPass-pass1-errorspan" style="display:none"></div>
# <input class="input style_input" id="resetPass-pass1" placeholder="Contrasenya *" type="password"/>
# </div>
# <div class="input-group">
# <div class="error_msg" id="resetPass-pass2-errorspan" style="display:none"></div>
# <input class="input style_input" id="resetPass-pass2" placeholder="Repeteix contrasenya *" type="password"/>
# </div>
# <br/>
# <button class="button" type="submit">Envia</button>
# </form>
# </ul>
# </div>
# </div>
# <div class="modal" id="statistics" style="display:none;">
# <div class="container">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <div id="graph_container" style="display: none;">
# <h2 class="header_with_mb"><b>El gràfic de la setmana</b></h2>
# <ul class="modal-content">
# <div class="chart-wrap vertical">
# <div class="grid" id="graph">
# <div class="bar" data-name="0%" id="day0" style="--bar-value:0%;" title="dl"></div>
# <div class="bar" data-name="0%" id="day1" style="--bar-value:0%;" title="dt"></div>
# <div class="bar" data-name="0%" id="day2" style="--bar-value:0%;" title="dc"></div>
# <div class="bar" data-name="0%" id="day3" style="--bar-value:0%;" title="dj"></div>
# <div class="bar" data-name="0%" id="day4" style="--bar-value:0%;" title="dv"></div>
# <div class="bar" data-name="0%" id="day5" style="--bar-value:0%;" title="ds"></div>
# <div class="bar" data-name="0%" id="day6" style="--bar-value:0%;" title="dg"></div>
# </div>
# </div>
# <div style="text-align: -webkit-center;text-align: -moz-center;">
# <div class="days">
# <div>dl.</div>
# <div>dt.</div>
# <div>dc.</div>
# <div>dj.</div>
# <div>dv.</div>
# <div>ds.</div>
# <div>dg.</div>
# </div>
# </div>
# </ul>
# <ul class="modal-content">
# <h2 style="margin-top: 40px;"><b>Les teves estadístiques</b></h2>
# <div class="input_group">
# <div class="stats-text">
#           Aquestes estadístiques es registren des del <div class="register_date" id="user_register_date"></div>,
#           que és el dia que et vas registrar al Paraulògic, i només són dades dels dies en què has jugat.
#         </div>
# <div class="stats" id="stats"></div>
# </div>
# </ul>
# </div>
# <div id="no_stats_container">
# <h2><b>Les teves estadístiques</b></h2>
# <div class="modal-content">
# <div class="input_group">
# <b>Aquesta funcionalitat és exclusiva per a usuaris registrats.</b> Per registrar-te i poder gaudir de tots els avantatges, només cal que omplis <a class="link" id="open_form" style="cursor: pointer;">aquest formulari</a>.
#             <br/>
# <br/>
#             Si ja tens un usuari del Paraulògic o ets subscriptor de VilaWeb, pots iniciar sessió fent clic <a class="link" id="open_login" style="cursor: pointer;">ací</a>.
#           </div>
# </div>
# </div>
# <div class="close-button-container">
# <button class="close-button" title="Tanca la finestra" type="button">Fet</button>
# </div>
# </div>
# </div>
# <div class="modal" id="instruccions" style="display:none;">
# <div class="container">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <h2>Normes</h2>
# <ul class="modal-content">
# <li>Cal formar paraules amb aquestes lletres. Les lletres es poden repetir.</li>
# <li>La lletra del mig és obligatòria.</li>
# <li>Les paraules han de tenir un mínim de 3 lletres.</li>
# <li>Dels verbs només s’admeten els infinitius (no les formes conjugades). Dels noms i adjectius s’admeten les formes masculina i femenina (no els plurals).</li>
# <li>No s’admeten noms propis; només paraules que figurin al Diccionari de la llengua catalana de l’Institut d’Estudis Catalans (<a href="//dlc.iec.cat/" rel="noopener" target="_blank" title="Diccionari de l’Institut d’Estudis Catalans">DIEC</a>). Tampoc s’admeten les paraules que formen part de locucions llatines.</li>
# </ul>
# <h2>Puntuació</h2>
# <ul class="modal-content">
# <li>Les paraules de 3 lletres donen 1 punt. Les de 4 lletres, 2 punts.</li>
# <li>A partir de 5 lletres, tants punts com lletres tingui la paraula.</li>
# <li>Cada joc inclou almenys un ‘tuti’ en què s’usen totes les lletres. Amb cada tuti obteniu 10 punts extra!</li>
# </ul>
# <h2>Preferències</h2>
# <div class="modal-content">
# <p><label><input checked="" id="expert" type="checkbox"/> Mostra la puntuació i el nombre de paraules possibles</label></p>
# <p><label><input checked="" id="def" type="checkbox"/> Mostra les definicions del DIEC automàticament</label></p>
# <p><label><input id="mute" type="checkbox"/> Silencia el so</label></p>
# <p class="book-hidden"><label><input id="dark" type="checkbox"/> Activa el mode fosc</label></p>
# </div>
# <h2>Crèdits</h2>
# <div class="modal-content">
# <p>Una iniciativa de <a href="//rodamots.cat" rel="noopener" target="_blank">Rodamots</a></p>
# <p>Idea i coordinació: Jordi Palou</p>
# <p>Programació: <a href="//orga.cat/" rel="noopener" target="_blank">Pere Orga</a></p>
# <p>Agraïments: Institut d’Estudis Catalans, Lou Hevly, Jaume Ortolà, Núria Ramoneda, Isabel Casadevall</p>
# <p>© Xarxa de Mots 2023. Tots els drets reservats.</p>
# </div>
# <div class="close-button-container">
# <button class="close-button" title="Tanca la finestra" type="button">Entesos</button>
# </div>
# </div>
# </div>
# <div class="modal" id="solucio" style="display:none;">
# <div class="container">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <h2>Solució del joc anterior</h2> <div class="words-yesterday-container">Lletres: <span id="words-yesterday"></span></div>
# <ul class="modal-content" id="solution-list"></ul>
# <div class="modal-content" id="found-yesterday"></div>
# <div class="close-button-container">
# <button class="close-button" title="Tanca la finestra" type="button">Entesos</button>
# </div>
# </div>
# </div>
# <div class="modal" id="pistes" style="display:none;">
# <div class="container">
# <div class="container-pistes">
# <div class="close-icon-container">
# <a class="close-icon-link" draggable="false" href="#">
# <img alt="Tanca" class="close-icon" draggable="false" src="img/close.svg" title="Tanca la finestra"/>
# </a>
# </div>
# <h2> Pistes </h2>
# <style>
#           td,
#           th {
#             width: 220px;
#             height: 20px;
#           }
#
#           table {
#             table-layout: auto;
#             width: 300px;
#           }
#         </style>
# <table id="table_graella">
# </table>
# <ul id="prefix2">
# <b class="pistes">Prefixos de dues lletres:</b>
# </ul>
# <ul id="prefix3">
# <b class="pistes">Prefix freqüent de tres lletres:</b>
# </ul>
# <ul id="sufix3">
# <b class="pistes">Sufixos freqüents de tres lletres:</b>
# </ul>
# <ul id="tutis">
# <b class="pistes">Hi ha X tutis:</b>
# </ul>
# <ul id="palindroms">
# <b class="pistes">Hi ha X palíndroms</b>
# </ul>
# <ul id="quadrats">
# <b class="pistes">Hi ha X mots quadrats de Y lletres:</b>
# </ul>
# <ul id="subconjunts">
# <b class="pistes">Subconjunts:</b>
# </ul>
# </div>
# </div>
# </div>
# <div class="nav-container">
# <nav>
# <button class="icon" id="options-link" title="Opcions" type="button">
# <div id="vlw-menu-hamburguesa">
# <div class="hamburguesa" id="vlw-hamburguesa">
# <span style="pointer-events: none;"></span>
# <span style="pointer-events: none;"></span>
# <span style="pointer-events: none;"></span>
# <span style="pointer-events: none;"></span>
# </div>
# </div>
# <div id="profile_icon" style="display: none;"></div>
# <div id="profile_text" style="display: none;"></div>
# </button>
# </nav>
# <nav class="options-nav" id="options-nav" style="display:none;">
# <button class="icon-secondary" id="instructions-link" title="Regles del joc" type="button-secondary"><svg aria-hidden="true" height="16" preserveaspectratio="xMidYMid meet" role="img" style="width:20px;height:20px" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g fill="currentColor">
# <path clip-rule="evenodd" d="M4.475 5.458c-.284 0-.514-.237-.47-.517C4.28 3.24 5.576 2 7.825 2c2.25 0 3.767 1.36 3.767 3.215c0 1.344-.665 2.288-1.79 2.973c-1.1.659-1.414 1.118-1.414 2.01v.03a.5.5 0 0 1-.5.5h-.77a.5.5 0 0 1-.5-.495l-.003-.2c-.043-1.221.477-2.001 1.645-2.712c1.03-.632 1.397-1.135 1.397-2.028c0-.979-.758-1.698-1.926-1.698c-1.009 0-1.71.529-1.938 1.402c-.066.254-.278.461-.54.461h-.777zM7.496 14c.622 0 1.095-.474 1.095-1.09c0-.618-.473-1.092-1.095-1.092c-.606 0-1.087.474-1.087 1.091S6.89 14 7.496 14z" fill="#000" fill-rule="evenodd"></path>
# </g>
# </svg></button>
# <a href="?data=2024-10-15" style="display:block"><button class="icon-secondary" id="date-link" title="Joc d'ahir" type="button-secondary">
# <svg height="459.000000pt" preserveaspectratio="xMidYMid meet" style="width:20px;height:20px" version="1.0" viewbox="0 0 457.000000 459.000000" width="457.000000pt" xmlns="http://www.w3.org/2000/svg">
# <g fill="#000000" stroke="none" transform="translate(0.000000,459.000000) scale(0.100000,-0.100000)">
# <path d="M763 4544 c-50 -25 -63 -65 -63 -198 l0 -116 -285 0 c-318 0 -339 -4 -375 -62 -20 -33 -20 -45 -20 -2043 0 -1998 0 -2010 20 -2043 41 -67 -128 -62 2247 -62 2034 0 2160 1 2193 18 20 10 42 32 52 52 17 33 18 151 18 2035 0 1884 -1 2002 -18 2034 -34 68 -51 71 -384 71 l-296 0 -4 130 -3 130 -33 32 -32 33 -124 3 c-203 6 -226 -16 -226 -212 l0 -116 -504 0 -504 0 -4 130 -3 130 -33 32 -32 33 -124 3 c-203 6 -226 -16 -226 -212 l0 -116 -439 0 -439 0 -4 130 -3 130 -33 32 -32 33 -128 3 c-101 2 -134 -1 -159 -14z m-63 -539 c0 -166 21 -185 210 -185 189 0 210 19 210 185 l0 95 440 0 440 0 0 -95 c0 -166 21 -185 210 -185 189 0 210 19 210 185 l0 95 505 0 505 0 0 -85 c0 -92 13 -132 52 -159 32 -23 284 -23 316 0 39 27 52 67 52 159 l0 85 285 0 285 0 0 -476 0 -476 -1082 6 c-596 3 -1557 9 -2135 12 l-1053 6 0 464 0 464 275 0 275 0 0 -95z m2688 -951 l1032 -6 0 -1449 0 -1449 -2135 0 -2135 0 0 1461 0 1461 1103 -6 c606 -3 1567 -9 2135 -12z"></path>
# <path d="M1523 1807 c-277 -139 -503 -254 -503 -257 0 -5 1005 -510 1015 -510 3 0 5 81 5 180 l0 180 645 0 645 0 0 150 0 150 -645 0 -645 0 0 180 c0 99 -3 180 -7 179 -5 0 -234 -113 -510 -252z"></path>
# </g>
# </svg>
# </button></a>
# <a href="" style="display:none"><button class="icon-secondary" id="date-link" title="Joc d'avui" type="button-secondary">
# <svg height="459.000000pt" preserveaspectratio="xMidYMid meet" style="width:20px;height:20px" version="1.0" viewbox="0 0 457.000000 459.000000" width="457.000000pt" xmlns="http://www.w3.org/2000/svg">
# <g fill="#000000" stroke="none" transform="translate(0.000000,459.000000) scale(0.100000,-0.100000)">
# <path d="M763 4544 c-50 -25 -63 -65 -63 -198 l0 -116 -285 0 c-318 0 -339 -4 -375 -62 -20 -33 -20 -45 -20 -2043 0 -1998 0 -2010 20 -2043 41 -67 -128 -62
#           2247 -62 2034 0 2160 1 2193 18 20 10 42 32 52 52 17 33 18 151 18 2035 0 1884 -1 2002 -18 2034 -34 68 -51 71 -384 71 l-296 0 -4 130 -3 130 -33 32 -32 33 -124 3 c-203 6 -226 -16 -226 -212 l0 -116 -504 0 -504 0 -4 130 -3
#           130 -33 32 -32 33 -124 3 c-203 6 -226 -16 -226 -212 l0 -116 -439 0 -439 0 -4 130 -3 130 -33 32 -32 33 -128 3 c-101 2 -134 -1 -159 -14z m-63 -539 c0
#           -166 21 -185 210 -185 189 0 210 19 210 185 l0 95 440 0 440 0 0 -95 c0 -166 21 -185 210 -185 189 0 210 19 210 185 l0 95 505 0 505 0 0 -85 c0 -92 13
#           -132 52 -159 32 -23 284 -23 316 0 39 27 52 67 52 159 l0 85 285 0 285 0 0 -476 0 -476 -1082 6 c-596 3 -1557 9 -2135 12 l-1053 6 0 464 0 464 275 0 275
#           0 0 -95z m2688 -951 l1032 -6 0 -1449 0 -1449 -2135 0 -2135 0 0 1461 0 1461 1103 -6 c606 -3 1567 -9 2135 -12z"></path>
# <path d="M2540 1880 l0 -180 -645 0 -645 0 0 -150 0 -150 645 0 645 0 0 -180 c0 -99 2 -180 5 -180 10 0 1015 505 1015 510 0 5 -1005 510 -1015 510 -3 0 -5 -81 -5 -180z"></path>
# </g>
# </svg>
# </button></a>
# <a><button class="icon-secondary" id="profile" title="Perfil" type="button-secondary">
# <svg fill="currentColor" height="20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M10 9a3 3 0 100-6 3 3 0 000 6zm-7 9a7 7 0 1114 0H3z" fill-rule="evenodd"></path>
# </svg>
# </button></a>
# <a><button class="icon-secondary" id="statistics_button" title="Estadístiques" type="button-secondary">
# <svg fill="currentColor" height="33pt" style="width:20px;height:20px" viewbox="0 0 33 33" width="33pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <defs>
# <clippath id="_clipPath_JdOjAEMu81N0nXE2skBdzIrLvvPtX80K">
# <rect height="33" width="33"></rect>
# </clippath>
# </defs>
# <g clip-path="url(#_clipPath_JdOjAEMu81N0nXE2skBdzIrLvvPtX80K)">
# <g>
# <line stroke="currentColor" stroke-linecap="square" stroke-linejoin="miter" stroke-miterlimit="3" stroke-width="3" vector-effect="non-scaling-stroke" x1="1" x2="31.663" y1="31" y2="31"></line>
# <rect fill="currentColor" height="27.702" transform="matrix(1,0,0,1,0,0)" width="8.326" x="0.674" y="0.109"></rect>
# <rect fill="currentColor" height="16.811" transform="matrix(1,0,0,1,0,0)" width="8.37" x="12.63" y="11"></rect>
# <rect fill="currentColor" height="20.811" transform="matrix(1,0,0,1,0,0)" width="8.152" x="24" y="7"></rect>
# </g>
# </g>
# </svg>
# </button></a>
# <a href="/minimots/"><button class="icon-secondary" id="date-link" title="Minimots" type="button-secondary">
# <svg height="32.000000pt" preserveaspectratio="xMidYMid meet" style="width:20px;height:20px" version="1.0" viewbox="0 0 32.000000 32.000000" width="32.000000pt" xmlns="http://www.w3.org/2000/svg">
# <g fill="#000000" stroke="none" transform="translate(0.000000,32.000000) scale(0.100000,-0.100000)">
# <path d="M0 160 l0 -160 160 0 160 0 0 160 0 160 -160 0 -160 0 0 -160z m100
#           100 l0 -50 -45 0 -45 0 0 50 0 50 45 0 45 0 0 -50z m108 3 l-3 -48 -47 -3 -48
#           -3 0 50 0 51 51 0 50 0 -3 -47z m-108 -108 l0 -45 -45 0 -45 0 0 45 0 45 45 0
#           45 0 0 -45z m210 0 l0 -45 -45 0 -45 0 0 45 0 45 45 0 45 0 0 -45z m-100 -100
#           l0 -45 -50 0 -50 0 0 45 0 45 50 0 50 0 0 -45z m100 0 l0 -45 -45 0 -45 0 0
#           45 0 45 45 0 45 0 0 -45z"></path>
# </g>
# </svg>
# </button></a>
# </nav>
# </div>
# <div class="container-notifications">
# <p class="hide-initial" id="message"> </p>
# </div>
# <div class="cursor-container">
# <p id="input-word"> <span id="test-word"></span><span id="cursor">|</span></p>
# </div>
# <div class="container-hexgrid">
# <ul id="hex-grid">
# <li class="hex">
# <div class="hex-in"><a class="hex-link">
# <p></p>
# </a></div>
# </li>
# <li class="hex">
# <div class="hex-in"><a class="hex-link">
# <p></p>
# </a></div>
# </li>
# <li class="hex">
# <div class="hex-in"><a class="hex-link">
# <p></p>
# </a></div>
# </li>
# <li class="hex">
# <div class="hex-in"><a class="hex-link" id="center-letter">
# <p></p>
# </a></div>
# </li>
# <li class="hex">
# <div class="hex-in"><a class="hex-link">
# <p></p>
# </a></div>
# </li>
# <li class="hex">
# <div class="hex-in"><a class="hex-link">
# <p></p>
# </a></div>
# </li>
# <li class="hex">
# <div class="hex-in"><a class="hex-link">
# <p></p>
# </a></div>
# </li>
# </ul>
# <div class="button-container">
# <button id="delete-button" title="Suprimeix l'última lletra" type="button">Suprimeix</button>
# <button aria-label="Barreja les lletres" class="icon" id="shuffle-button" title="Barreja les lletres" type="button">
# <svg aria-hidden="true" focusable="false" role="img" viewbox="0 0 512 512" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M370.72 133.28C339.458 104.008 298.888 87.962 255.848 88c-77.458.068-144.328 53.178-162.791 126.85-1.344 5.363-6.122 9.15-11.651 9.15H24.103c-7.498 0-13.194-6.807-11.807-14.176C33.933 94.924 134.813 8 256 8c66.448 0 126.791 26.136 171.315 68.685L463.03 40.97C478.149 25.851 504 36.559 504 57.941V192c0 13.255-10.745 24-24 24H345.941c-21.382 0-32.09-25.851-16.971-40.971l41.75-41.749zM32 296h134.059c21.382 0 32.09 25.851 16.971 40.971l-41.75 41.75c31.262 29.273 71.835 45.319 114.876 45.28 77.418-.07 144.315-53.144 162.787-126.849 1.344-5.363 6.122-9.15 11.651-9.15h57.304c7.498 0 13.194 6.807 11.807 14.176C478.067 417.076 377.187 504 256 504c-66.448 0-126.791-26.136-171.315-68.685L48.97 471.03C33.851 486.149 8 475.441 8 454.059V320c0-13.255 10.745-24 24-24z" fill="currentColor"></path>
# </svg>
# </button>
# <button id="submit-button" title="Introdueix la paraula" type="button">Introdueix</button>
# </div>
# </div>
# <div class="scoreboard">
# <div id="definition"></div>
# <div>Has trobat <span id="letters-found">0</span> <span id="found-suffix">paraules</span><span id="discovered-text">.</span></div>
# <div id="score"></div>
# <div id="level"></div>
# <div id="stars"></div>
# <div>
# <a id="num_joc_container" style="display:none;text-decoration: none;"></a><a href="#solucio" id="solution-link">Solució d’ahir</a> | <a href="#pistes" id="pistes-link">Pistes</a> | <a href="#compartir" id="share-link">
# <svg height="20px" preserveaspectratio="xMidYMid meet" style="vertical-align: sub" version="1.0" viewbox="0 0 512.000000 512.000000" width="20px" xmlns="http://www.w3.org/2000/svg">
# <g fill="#000000" stroke="currentColor" transform="translate(0.000000,512.000000) scale(0.100000,-0.100000)">
# <path d="M3200 3862 l0 -299 -123 -6 c-289 -15 -552 -99 -777 -250 -106 -71 -293 -261 -369 -377 -121 -182 -207 -382 -267 -616 -31 -125 -69 -354 -62 -375 2 -6 26 25 53 68 328 524 615 751 1055 833 116 22 305 40 418 40 l72 0 0 -320 0 -319 639 477 640 477 -32 25 c-17 14 -305 231 -639 483 l-608 457 0 -298z"></path>
# <path d="M755 3501 c-48 -22 -79 -54 -100 -103 -13 -33 -15 -169 -15 -1158 0 -989 2 -1125 15 -1158 20 -47 50 -79 97 -103 37 -19 77 -19 1531 -17 l1493 3 42 28 c23 15 51 45 62 67 20 39 20 54 18 606 l-3 567 -187 -154 -188 -153 0 -293 0 -293 -1250 0 -1250 0 2 898 3 897 283 3 283 2 112 114 c62 62 158 148 215 190 l103 76 -613 0 c-575 0 -616 -2 -653 -19z"></path>
# </g>
# </svg></a> </div>
# </div>
# <div id="bottom-banner" style="display:none;position:fixed;bottom: 0;text-align: center;width: 100%;left: 0;background-color: #63BCCA; color: #FFF;">
# <p id="bottom-banner-text" style="padding: 10px; line-height: 25px;"></p>
# <div id="bottom-banner-close" style="position: absolute;right: 0;top: -30px;background-color: #63BCCA;width: 30px;height: 30px; cursor:pointer;">X</div>
# </div>
# <script>
#     document.getElementById("bottom-banner-close").onclick = function(e) {
#       e.preventDefault(), document.getElementById("bottom-banner").style.display = "none"
#     };
#   </script>
# <script>
#     /*!
#      * Desenvolupat per Pere Orga <pere@orga.cat>, 2021.
#      * Originalment basat en https://github.com/lzha97/spelling_bee (Apache License 2.0).
#      * Inclou la lletra Open Sans (Apache License 2.0), imatges del projecte Noto Emoji (SIL Open Font License 1.1) i icones dels projectes Font Awesome (Creative Commons Attribution 4.0) i Bootstrap (MIT License).
#      * Alguns sons s'han extret de https://freesound.org/people/DrinkingWindGames/sounds/572954/, https://freesound.org/people/soundbytez/sounds/111074/ i https://freesound.org/people/Benboncan/sounds/64544/, tots tres amb llicència Creative Commons Attribution 3.0.
#      */
#     var y={"l":["a","c","i","s","t","v"],"p":{"activa": "activa","activista": "activista","activitat": "activitat","atavic": "atàvic","atavica": "atàvica","avi": "avi","avia": "àvia","aviat": "aviat","avis": "avís","avisat": "avisat","cava": "cava","cavista": "cavista","cavitat": "cavitat","civic": "cívic","civica": "cívica","vist": "en vist","iva": "iva","sativa": "sativa","savi": "savi","savia": "sàvia","sisavat": "sisavat","tava": "tavà","vaca": "vaca","vacassa": "vacassa","vacci": "vaccí","vas": "vas","vasa": "vasa","vast": "vast","vasta": "vasta","vatica": "vaticà","via": "via","viat": "viat","viatic": "viàtic","vici": "vici","viciat": "viciat","vis": "vis","visavis": "vis-a-vis","visat": "visat","visc": "visc","visca": "visca","visita": "visita","visiva": "visiva","vista": "vista","vit": "vit","vitacia": "vitàcia","viva": "viva","vivacitat": "vivacitat"},"has_banner": "1","text_banner":"<p><a href=\"https://www.vilaweb.cat/paraulogic/lliga/?fase=1\" target=\"_blank\">Encara pots jugar a la Lliga del Paraulògic. Juga-hi i passa-t\'ho bé!</a></p>","max_vistes_banner":100,"color_banner":"#63bcca","pistes":"{'prefixos-2': {'ac': 3, 'at': 2, 'av': 5, 'ca': 3, 'ci': 2, 'vi': 18, 'iv': 1, 'sa': 3, 'si': 1, 'ta': 1, 'va': 8}, 'prefix': {'prefixos': ['vis'], 'freq': 9}, 'sufix-3': {'iva': 5}, 'tutis': {'9': 1, '7': 1}, 'palindroms': {'5': 1}, 'quadrats': {}, 'subconjunts': {'acitv': 10, 'acistv': 2, 'aiv': 5, 'aitv': 2, 'aisv': 5, 'aistv': 6, 'acv': 2, 'civ': 2, 'aciv': 2, 'istv': 1, 'atv': 1, 'acsv': 1, 'asv': 2, 'astv': 2, 'isv': 1, 'cisv': 1, 'acisv': 1, 'itv': 1}, 'graella': [',&nbsp;3,&nbsp;4,&nbsp;5,&nbsp;6,&nbsp;7,&nbsp;8,&nbsp;9,\u03a3', 'a,1,2,1,3,1,0,2,10', 'c,0,1,1,1,2,0,0,5', 'i,1,0,0,0,0,0,0,1', 's,0,1,1,1,1,0,0,4', 't,0,1,0,0,0,0,0,1', 'v,4,8,5,5,3,0,1,26', '\u03a3,6,13,8,10,7,0,3,47,']}\n"};var t={"l":["b","o","s","t","u","r"],"p":{"bor": "bor","borro": "borró","borros": "borrós","borrut": "borrut","borur": "borur","brossos": "brossós","brot": "brot","broto": "brotó","brou": "brou","brouos": "brouós","bru": "bru","brut": "brut","brutor": "brutor","buro": "buró","burot": "burot","burro": "burro","orb": "orb","oro": "oró","oros": "oros","orto": "orto","robot": "robot","robust": "robust","ros": "ros","rossor": "rossor","rost": "rost","rot": "rot","rotor": "rotor","rou": "rou","rouro": "rouró","rubor": "rubor","ruboros": "ruborós","rus": "rus","sor": "sor","sorros": "sorrós","sorrut": "sorrut","sort": "sort","sortos": "sortós","sorus": "sorus","suor": "suor","suro": "suro","suros": "surós","surt": "surt","tor": "tor","torb": "torb","torbos": "torbós","toro": "toro","torr": "torr","torro": "torró","tors": "tors","tort": "tort","torto": "tortó","tortuos": "tortuós","torus": "torus","tostorro": "tostorro","tro": "tro","tros": "tros","trot": "trot","troto": "trotó","trust": "trust","tur": "tur","turborotor": "turborotor","turbot": "turbot","turo": "turo o turó","tururut": "tururut","tussor": "tussor","tutor": "tutor","urbs": "urbs","urubu": "urubú"},"has_banner": "1","text_banner":"<p><a href=\"https://www.vilaweb.cat/paraulogic/lliga/?fase=1\" target=\"_blank\">Continua jugant a la Lliga del Paraulògic i passa-t\'ho bé!</a></p>","max_vistes_banner":100,"color_banner":"#63bcca","pistes":"{'prefixos-2': {'bo': 5, 'br': 8, 'bu': 3, 'or': 4, 'ro': 9, 'ru': 3, 'so': 6, 'su': 4, 'to': 12, 'tr': 5, 'tu': 7, 'ur': 2}, 'prefix': {'prefixos': ['tor'], 'freq': 11}, 'sufix-3': {'ros': 7}, 'tutis': {'6': 1}, 'palindroms': {'3': 1, '6': 2, '5': 1, '7': 1}, 'quadrats': {}, 'subconjunts': {'bor': 3, 'bors': 2, 'bortu': 5, 'boru': 5, 'bort': 4, 'borsu': 2, 'bru': 2, 'brtu': 1, 'or': 1, 'ors': 5, 'ort': 12, 'borstu': 1, 'orst': 6, 'oru': 2, 'rsu': 1, 'orstu': 4, 'orsu': 4, 'rstu': 2, 'borst': 1, 'rtu': 2, 'ortu': 2, 'brsu': 1}, 'graella': [',&nbsp;3,&nbsp;4,&nbsp;5,&nbsp;6,&nbsp;7,&nbsp;8,&nbsp;9,10,\u03a3', 'b,2,4,5,4,1,0,0,0,16', 'o,2,2,0,0,0,0,0,0,4', 'r,4,1,4,2,1,0,0,0,12', 's,1,4,2,3,0,0,0,0,10', 't,3,8,6,3,2,1,0,1,24', 'u,0,1,1,0,0,0 ...
#   </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-T4002DY5P3"></script>
# <script type="text/javascript">
#     window.dataLayer = window.dataLayer || [];
#
#     function gtag() {
#       dataLayer.push(arguments);
#     }
#     gtag('js', new Date());
#
#     gtag('config', 'G-T4002DY5P3');
#     gtag('config', 'UA-38602294-1');
#     if (typeof _cbq !== 'undefined') _cbq.push(['_acct', 'anon']);
#
#     setTimeout(function() {
#       gtag("event", "NoBounce", {
#         event_category: "NoBounce",
#         event_label: "event 10 segons"
#     });
#   },10*1000);
# </script>
# <div class="interstitial" id="interstitial" style="display:none;">
# <div class="container">
# <div class="close-banner" onclick="this.parentNode.parentNode.style.display='none'">
# <div>
# <svg fill="none" height="24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M17.834 4.84L4.84 17.835a.188.188 0 000 .265l1.06 1.06a.188.188 0 00.265 0L19.16 6.167a.188.188 0 000-.265l-1.06-1.06a.188.188 0 00-.265 0z" fill="currentColor"></path><path d="M19.16 17.834L6.166 4.84a.188.188 0 00-.265 0L4.841 5.9a.188.188 0 000 .265L17.834 19.16a.188.188 0 00.265 0l1.06-1.061a.188.188 0 000-.265z" fill="currentColor"></path></svg>
# </div>
# </div>
# <div class="banner-container" id="div-gpt-ad-1678720458858-0">
# <script>
#             if ( localStorage.getItem('prl_interstitial') == null || parseInt(localStorage.getItem('prl_interstitial')) + 86400000 < Date.now() ) {
#               localStorage.setItem('prl_interstitial', Date.now());
#               googletag.cmd.push(function() { googletag.display('div-gpt-ad-1678720458858-0'); });
#               setTimeout(() => {
#                 document.getElementById('interstitial').style.display = 'block';
#               }, 2000);
#             }
#         </script>
# </div>
# </div>
# </div>
# </body>
# </html>
# P Text:
# P Text:
# P Text:
# P Text:
# P Text:
# P Text:
# P Text:

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

# %%
# Path to your ChromeDriver executable
driver_path = '/path/to/chromedriver'  # Replace with your chromedriver path
service = Service(driver_path)

# Initialize the Chrome driver
driver = webdriver.Chrome(service=service)

# URL of the webpage you want to scrape
url = 'https://www.vilaweb.cat/paraulogic/'  # Replace with your target URL

# Open the webpage
driver.get(url)

# Give time for JavaScript to load the content
time.sleep(3)  # Adjust the sleep time if the page needs more time to load

# Find all DIVs with class 'hex-in'
divs = driver.find_elements(By.CLASS_NAME, 'hex-in')

# Loop through each div to access the nested structure
for div in divs:
    # Find the <a> tag with the class 'hex-link'
    a_tag = div.find_element(By.CLASS_NAME, 'hex-link')
    
    # Find the <p> tag inside the <a> tag
    p_tag = a_tag.find_element(By.TAG_NAME, 'p')
    
    # Get the text inside the <p> tag
    p_text = p_tag.text
    print(f"P Text: {p_text}")

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: /path/to/chromedriver
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[2], line 6
#       3 service = Service(driver_path)
#       5 # Initialize the Chrome driver
# ----> 6 driver = webdriver.Chrome(service=service)
#       8 # URL of the webpage you want to scrape
#       9 url = 'https://example.com'  # Replace with your target URL
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:50, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      47 self.service = service
#      49 finder = DriverFinder(self.service, options)
# ---> 50 if finder.get_browser_path():
#      51     options.binary_location = finder.get_browser_path()
#      52     options.browser_version = None
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\driver_finder.py:47, in DriverFinder.get_browser_path(self)
#      46 def get_browser_path(self) -> str:
# ---> 47     return self._binary_paths()["browser_path"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\common\driver_finder.py:78, in DriverFinder._binary_paths(self)
#      76 except Exception as err:
#      77     msg = f"Unable to obtain driver for {browser}"
# ---> 78     raise NoSuchDriverException(msg) from err
#      79 return self._paths
#
# NoSuchDriverException: Message: Unable to obtain driver for chrome; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location
